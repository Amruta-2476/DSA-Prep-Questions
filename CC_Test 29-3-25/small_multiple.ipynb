# %% [markdown]
# ![{C41E0E93-0020-4E5A-A0DB-E05D3F432524}.png](attachment:{C41E0E93-0020-4E5A-A0DB-E05D3F432524}.png)

# %%
n = int(input())
result = 1

for i in range(2, n+1):
  a,b = result,i
  while b:
    a,b = b, a%b
  # LCM
  result = (result*i) // a      
  
print(result)
# Out:
# 2520
