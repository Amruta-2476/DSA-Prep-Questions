# %% [markdown]
# ![{03A9C431-32CB-489C-9E95-6C7B129C4ADD}.png](attachment:{03A9C431-32CB-489C-9E95-6C7B129C4ADD}.png)

# %% [markdown]
# ![{D0B220D4-0B50-46D4-9DA4-C659EDF4AAE2}.png](attachment:{D0B220D4-0B50-46D4-9DA4-C659EDF4AAE2}.png)

# %%
#!/bin/python3
import math
import os
import random
import re
import sys

# Complete the 'rotateLeft' function below.
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER d
#  2. INTEGER_ARRAY arr
#

def rotateLeft(d, arr):
    for i in range(d):
        arr.append(arr[0])
        # print(arr)
        arr.remove(arr[0])
        # print(arr)
    return arr


if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = int(first_multiple_input[0])

    d = int(first_multiple_input[1])

    arr = list(map(int, input().rstrip().split()))

    result = rotateLeft(d, arr)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %% [markdown]
# ![{0200707B-CB6D-4AD8-B0EF-19DC60D8E9EB}.png](attachment:{0200707B-CB6D-4AD8-B0EF-19DC60D8E9EB}.png)

# %%
class Solution(object):
    def rotate(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        l = len(nums)   # l = 7
        k = k%l
        # print(nums[:(l-k)])
        # print(nums[(l-k):])
        nums[:] = nums[(l-k):] + nums[:(l-k)]

# %%
class Solution(object):
    def rotate(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        n = len(nums)
        k %= n  # Handle cases where k is greater than n
        
        # Helper function to reverse a part of the array
        def reverse(start, end):
            while start < end:
                nums[start], nums[end] = nums[end], nums[start]
                start += 1
                end -= 1
        
        # Reverse the entire array
        reverse(0, n - 1)
        # Reverse the first k elements
        reverse(0, k - 1)
        # Reverse the remaining elements
        reverse(k, n - 1)

# %% [markdown]
# https://chatgpt.com/share/67e2f580-1af4-800a-9c43-01bd9fc66cd4
