# %% [markdown]
# ![{93ACAA71-D601-4A1B-BC9B-D9DD389EC68F}.png](attachment:{93ACAA71-D601-4A1B-BC9B-D9DD389EC68F}.png)

# %% [markdown]
# ![{79E89852-1EB1-4173-A7D7-A0073C3F0F01}.png](attachment:{79E89852-1EB1-4173-A7D7-A0073C3F0F01}.png)

# %% [markdown]
# ![{03745217-5E9E-4D0A-9AC2-95583C1219FE}.png](attachment:{03745217-5E9E-4D0A-9AC2-95583C1219FE}.png)

# %%
import math
import os
import random
import re
import sys

# Complete the 'hourglassSum' function below.
# The function is expected to return an INTEGER.
# The function accepts 2D_INTEGER_ARRAY arr as parameter.

def hourglassSum(arr):
    hg_sums = []
    sum = 0
    for i in range(4):
        for j in range(4):
            sum = arr[i][j]+arr[i][j+1]+arr[i][j+2] + arr[i+1][j+1] + arr[i+2][j]+arr[i+2][j+1]+arr[i+2][j+2]
            hg_sums.append(sum)
    # print(hg_sums) 
    return(max(hg_sums)) 
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')
    arr = []
    for _ in range(6):
        arr.append(list(map(int, input().rstrip().split())))
    result = hourglassSum(arr)
    fptr.write(str(result) + '\n')
    fptr.close()
