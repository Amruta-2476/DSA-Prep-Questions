# %% [markdown]
# ![{CC5D7D64-7D95-4F5D-B86F-3F2A510CAADA}.png](attachment:{CC5D7D64-7D95-4F5D-B86F-3F2A510CAADA}.png)

# %%
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        # 178/212 passed (prices = [3,2,6,5,0,3]   my_op=3   expected=4)
        # smallest_index = 0
        # for i in range(len(prices)-1):
        #     if prices[i] < prices[smallest_index]:
        #         smallest_index = i
        # # print(smallest_index)
        # max_profit = 0
        # for i in range(smallest_index+1, len(prices)):  # (2 3 4 5) 5 3 6 4
        #     if (prices[i] - prices[smallest_index]) > max_profit:
        #         max_profit = (prices[i] - prices[smallest_index])
        # return(max_profit)


        # 198 / 212 passed   (time limit exceeded :( ..)
        profits = []   # 3,2, 4,3,1, 3
        for i in range(len(prices)):
            for j in range(i+1, len(prices)):
                if prices[j] > prices[i]:
                    profits.append(prices[j]-prices[i])
        # print(profits)
        if len(profits) == 0:
            return 0
        else:
            max_prof = max(profits)
            return max_prof

# %% [markdown]
# Your 2nd approach is correct in terms of logic, but it's inefficient because you're using a brute-force approach with O(n²) time complexity.
#
# Why is your method slow? You have two nested loops

# %%
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """

        min_price = prices[0]
        max_price = 0
        for i in range(len(prices)):
            if prices[i] < min_price:
                min_price = prices[i]
            else:
                max_price = max(max_price, prices[i] - min_price)
        return max_price
