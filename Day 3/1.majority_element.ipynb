# %% [markdown]
# ![{5A6DC332-AD05-4467-BDFD-23C4374CF73A}.png](attachment:{5A6DC332-AD05-4467-BDFD-23C4374CF73A}.png)

# %%
class Solution(object):
    def majorityElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        # 1st way:       42 / 52 testcases passed
        # def count(num):  (same issue even if using .count() directly)
        #     count = 0
        #     for i in range(len(nums)):
        #         if nums[i] == num:
        #             count = count + 1
        #     return count
        # myDict = {}
        # for i in range(len(nums)):
        #     myDict[nums[i]] = nums.count(nums[i])
        # # print(myDict.values())
        # for i,j in myDict.items():
        #     # print(i,j)
        #     if j >= (len(nums)//2):
        #         return i


        # 2nd way:   43/52 testcases passed
        # print(len(nums)//2)
        # for i in range(len(nums)):
        #     if nums.count(nums[i]) > (len(nums)//2):
        #         print(nums.count(nums[i]))
        #         return nums[i]
        

        # 3rd way: :(   ........ Yay
        freq = {}
        for i in range(len(nums)):
            if nums[i] not in freq:
                freq[nums[i]] = 1
            else:
                freq[nums[i]] = freq[nums[i]] + 1
        for i in freq:
            if freq[i] > len(nums)//2:
                return i
